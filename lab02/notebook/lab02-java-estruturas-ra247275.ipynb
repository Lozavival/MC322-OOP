// %% [markdown]
// # Laboratório em Estruturas de Programação Java
//
// O laboratório a seguir serve para praticar estruturas de programação Java sem compromisso com a orientação a objetos.

// %% [markdown]
// ## Desafio 1 - Empréstimo
//
// Em um financiamento com juros compostos e número de parcelas fixas parte-se dos seguintes parâmetros:
// * `S` - valor da primeira parcela
// * `N` - número de parcelas
// * `J` - percentual de juros mensal
//
// A primeira parcela a ser paga do financiamento é sempre igual a `S`. A partir daí é feita uma atualização mensal da parcela, em que cada nova parcela é calculada a partir da parcela do mês anterior, conforme a fórmula:
//
// > Parcela<sub>mês</sub> = Parcela<sub>mês-1</sub> * (1 + `J` / 100)
//
// O financiamento encerra quando as `N` parcelas são pagas.
//
// Exemplo:
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// Parcelas do financiamento:
// `200`; `202`; `204.02`; `206.06`; `208.12`

// %% [markdown]
// ### Desafio 1 / Parte 1 - Escrevendo o programa sem módulos
//
// Dado o problema descrito, escreva um programa que calcule as parcelas de um empréstimo para os seguintes valores:
// * S: 200
// * N: 5
// * J: 1%
//
// Nesta versão não use outro módulo além da função principal.

// %%
import java.text.DecimalFormat;

DecimalFormat formato = new DecimalFormat(".00");

int s = 200,
    n = 5,
    j = 1;
float parcela_atual = s;

for (int i = 1; i < n+1; i++) {
    System.out.println(i + "a parcela: " + formato.format(parcela_atual));
    parcela_atual = parcela_atual + parcela_atual * j/100;
}
// Out:
// 1a parcela: 200.00
// 2a parcela: 202.00
// 3a parcela: 204.02
// 4a parcela: 206.06
// 5a parcela: 208.12
// null

// %% [markdown]
// ### Desafio 1 / Parte 2 - Escrevendo módulos
//
// Reescreva o código acima de forma que seu programa faça uso de uma função que seja responsável pelo cálculo de uma parcela X do empréstimo. Podem ser usadas mais funções (métodos) conforme a necessidade.

// %%
public class Emprestimo {
    
    static float calculaParcela(int s, int n, int j, int parcela_corrente, float valor_atual) {
        float valor_parcela = s;
        if (parcela_corrente > n)
            valor_parcela = 0;
        else if (parcela_corrente > 1)
            valor_parcela = valor_atual + valor_atual * j/100;
        return valor_parcela;
    }

}
// Out:
// com.twosigma.beaker.javash.bkr0bbfdee0.Emprestimo

// %%
import java.text.DecimalFormat;

DecimalFormat formato = new DecimalFormat(".00");

int s = 200,
    n = 5,
    j = 1,
    parcela_corrente = 1;
float parcela_atual = s;

for (int i = 1; i < n+1; i++) {
    System.out.println(i + "a parcela: " + formato.format(parcela_atual));
    parcela_corrente++;
    parcela_atual = Emprestimo.calculaParcela(s, n, j, parcela_corrente, parcela_atual);
}
// Out:
// 1a parcela: 200.00
// 2a parcela: 202.00
// 3a parcela: 204.02
// 4a parcela: 206.06
// 5a parcela: 208.12
// null

// %% [markdown]
// ## Desafio 2
//
// Escreva um programa que sorteie um número inteiro entre `0` e `9999` o número deve ser mostrado, em seguida convertido para binário e a versão binária deve ser apresentada no console. A conversão decimal/binário deve ser computada por um programa feito por você.

// %%
public class Binario {
    
    static String converteParaBinario(int decimal) {
        int quociente = decimal, resto;
        String bin = "";
        
        while (quociente > 0) {
            resto = quociente % 2;
            quociente = quociente / 2;
            bin = resto + bin;
        }
        
        return bin;
    }
    
}
// Out:
// com.twosigma.beaker.javash.bkr0bbfdee0.Binario

// %%
import java.util.Random;

Random rand = new Random();
int sorteado = rand.nextInt(10000);

System.out.println("Número sorteado: " + sorteado);
System.out.println("Número convertido para binário: " + Binario.converteParaBinario(sorteado));
// Out:
// Número sorteado: 6492
// Número convertido para binário: 1100101011100
// null

// %% [markdown]
// ## Desafio 3
//
// Uma molécula de DNA pode ser definida a partir de uma cadeia que representa a sequência de suas bases:
// A - Adenina
// C - Citisina
// G - Guanina
// T - Tinina
//
// Desse modo, uma string pode ser usada para representar um segmento do DNA da seguinte maneira: `ATTACGCGCAAAC`.
//
// Escreva uma função (método) que codifique a cadeia de RNA produzida a partir de uma cadeia de DNA. A função deve ser genérica o suficiente para ser aplicável a qualquer cadeia. A entrada é uma string (DNA) e o retorno é uma string (RNA).
//
// Escreva um programa que teste esta função com uma cadeia de DNA de sua escolha.

// %%
public class Transcricao {

    static String transcreveDna(String Dna) {
        String Rna = "";
        
        for (int i = 0; i < Dna.length(); i++) {
            switch (Dna.charAt(i)) {
                case 'A' :
                    Rna += "U";
                    break;
                case 'C' :
                    Rna += "G";
                    break;
                case 'G' :
                    Rna += "C";
                    break;
                case 'T' :
                    Rna += "A";
                    break;
            }
        }
        
        return Rna;
    }

}
// Out:
// com.twosigma.beaker.javash.bkr0bbfdee0.Transcricao

// %%
String Dna = "TACGATCTCGCAATC",
       Rna_buscado = "AUGCUAGAGCGUUAG",
       Rna_obtido = Transcricao.transcreveDna(Dna);

// Informa o a cadeia de DNA original e a cadeia de RNA obtida pela função Transcricao.transcreveDna
System.out.println("DNA original: " + Dna);
System.out.println("RNA obtido: " + Rna_obtido);

// Verifica (e imprime) se a cadeia de RNA obida está correta
if (Rna_obtido.equals(Rna_buscado))
    System.out.println("O RNA obtido está correto!");
else
    System.out.println("O RNA obtido está incorreto!\nRNA correto: " + Rna_buscado);
// Out:
// DNA original: TACGATCTCGCAATC
// RNA obtido: AUGCUAGAGCGUUAG
// O RNA obtido está correto!
// null

// %% [markdown]
// ## Desafio 4
//
// Uma empresa precisa realizar uma estatística do salário de seus funcionários.
//
// Para fins de teste, os salários devem ser gerados aleatoriamente com valores variando entre R\\$ 2.500 e R\\$ 15.000.
//
// Escreva um programa que gere uma lista contendo os salários de 50 funcionários da empresa e mostre no console quantos funcionários ganham salário acima da média.

// %%
import java.util.Random;

Random rand = new Random();
int sorteado,
    num_acima = 0,
    salarios[] = new int[50];
float media = 0;

// Gera os valores dos salários (e os adiciona ao vetor) e atualiza a média
for (int i = 0; i < 50; i++) {
    sorteado = rand.nextInt(15001) + 2500;
    salarios[i] = sorteado;
    media += sorteado / 50;
}

// Verifica e conta quantos salários estão acima da média
for (int i = 0; i < 50; i++)
    if (salarios[i] > media)
        num_acima++;

System.out.println(num_acima + " funcionários ganham salário acima da média.");
// Out:
// 24 funcionários ganham salário acima da média.
// null
